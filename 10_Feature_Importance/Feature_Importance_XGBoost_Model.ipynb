# %% [markdown]
# # Feature Importance

# %%
importances = xg.feature_importances_
importance = pd.DataFrame(importances,index=X.columns)
importance = importance.reset_index()
importance.columns = ['feature','importance']
importance = importance.sort_values('importance',ascending=False)
importance = importance.reset_index(drop=True)

# %%
importance
# Out:
#                    feature  importance
# 0                    grade    0.453751
# 1                sub_grade    0.185266
# 2                 int_rate    0.064246
# 3                     term    0.042383
# 4         t_inq_last_6mths    0.019599
# 5           home_ownership    0.018344
# 6               emp_length    0.016296
# 7                loan_amnt    0.012659
# 8           num_actv_bc_tl    0.011739
# 9      verification_status    0.009643
# 10             avg_cur_bal    0.009122
# 11                 issue_d    0.008137
# 12             installment    0.007905
# 13           t_open_il_12m    0.007616
# 14         tot_hi_cred_lim    0.007137
# 15           num_op_rev_tl    0.007128
# 16               num_il_tl    0.006222
# 17              addr_state    0.005971
# 18          total_bc_limit    0.005853
# 19               t_pub_rec    0.005779
# 20               revol_bal    0.005775
# 21                coborrow    0.005623
# 22    t_num_tl_90g_dpd_24m    0.005467
# 23                     dti    0.005230
# 24              annual_inc    0.005194
# 25  t_pub_rec_bankruptcies    0.004743
# 26                 purpose    0.004594
# 27          open_rev_ratio    0.004414
# 28           time_until_fc    0.004319
# 29        earliest_cr_line    0.004309
# 30             t_tax_liens    0.004256
# 31           t_delinq_2yrs    0.004218
# 32   num_accts_ever_120_pd    0.004184
# 33             tot_cur_bal    0.004174
# 34              revol_util    0.004143
# 35        percent_bc_gt_75    0.003886
# 36               num_bc_tl    0.003669
# 37       total_bal_ex_mort    0.003576
# 38           num_rev_accts    0.003563
# 39         active_ratio_bc    0.003476
# 40               total_acc    0.003203
# 41                open_acc    0.003187
